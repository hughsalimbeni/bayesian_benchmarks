# %%
# %%javascript
# IPython.OutputArea.auto_scroll_threshold = 9999;

# %%
from matplotlib import pyplot
import numpy as np
import pandas
from matplotlib import pyplot as plt
from scipy.stats import rankdata

import sys
sys.path.append('../../')
from bayesian_benchmarks.database_utils import Database
from bayesian_benchmarks.data import classification_datasets, _ALL_REGRESSION_DATATSETS, _ALL_CLASSIFICATION_DATATSETS
ALL_DATATSETS = {}
ALL_DATATSETS.update(_ALL_REGRESSION_DATATSETS)
ALL_DATATSETS.update(_ALL_CLASSIFICATION_DATATSETS)

from IPython.display import display, HTML
# Out:
# /homes/hrs13/Documents/github/bayesian_benchmarks/bayesian_benchmarks

# %%
def rankarray(A):
    ranks = []
    for a in A:
        ranks.append(rankdata(a))
    return np.array(ranks)


def read_regression_classification(fs, models_names, datasets, task):
    if task == 'classification':
        fields = ['dataset', 'N', 'D', 'K'] + [m[1] for m in models_names]
    else:
        fields = ['dataset', 'N', 'D'] + [m[1] for m in models_names]

    results = {}
    for f in fs:
        results[f] = {'table':{f:[] for f in fields}, 'vals':[]}

    with Database('../results/results.db') as db:

        for dataset in datasets:
            for f in fs:
                results[f]['table']['dataset'].append(dataset[:10])
                results[f]['table']['N'].append(ALL_DATATSETS[dataset].N)
                results[f]['table']['D'].append(ALL_DATATSETS[dataset].D)
                if task == 'classification':
                    results[f]['table']['K'].append(ALL_DATATSETS[dataset].K)

            row = {f:[] for f in fs}
            for model, name in models_names:
                res = db.read(task, fs, {'model':model, 
                                         'dataset':dataset})
                    
                if len(res) == 0:
                    for f in fs:
                        results[f]['table'][name].append('')
                        row[f].append(np.nan)
                else:
                    print('{} {} {}'.format(model, dataset, len(res)))
                    for i, f in enumerate(fs):
                        L = [float(l[i]) for l in res]
                        m = np.average(L)
                        std = np.std(L) if len(L) > 1 else np.nan
                        if m < 1000 and m > -1000:
                            r = '{:.3f}({:.3f})'.format(m, std)
                            row[f].append(m)
                        else:
                            r = 'nan'
                            row[f].append(np.nan)

                        results[f]['table'][name].append(r)

            #             stderr = np.std(L)/float(len(L))**0.5
            #             r = '{:.3f} ({:.3f})'.format(m, stderr)
            for f in fs:   
                results[f]['vals'].append(row[f])


    for f in fs:
        if 'unnormalized' not in f:
            vals = np.array(results[f]['vals'])

            avgs = np.nanmean(vals, 0)
            meds = np.nanmedian(vals, 0)
            rks = np.nanmean(rankarray(vals), 0)

            for s, n in [[avgs, 'avg'], [meds, 'median'], [rks, 'avg rank']]:
                results[f]['table']['dataset'].append(n)
                results[f]['table']['N'].append('')
                results[f]['table']['D'].append('')
                if task == 'classification':
                    results[f]['table']['K'].append('')
                for ss, name in zip(s, [m[1] for m in models_names]):
                    results[f]['table'][name].append('{:.3f}'.format(ss))
    
    return results, fields

# %%
models_names = [['linear', 'lin'],
                ['variationally_sparse_gp', 'SVGP'],
                ['variationally_sparse_gp_minibatch', 'SVGP_mb'],
                ['deep_gp_doubly_stochastic','DGP'],
                ['svm', 'svm'],
                ['knn', 'knn'],
#                 ['naive_bayes', 'nb'],
#                 ['decision_tree', 'dt'],
#                 ['random_forest', 'rf'],
                ['gradient_boosting_machine', 'gbm'],
                ['adaboost', 'ab'],
                ['mlp', 'mlp'],
                ]

fs = 'test_loglik', 'test_rmse', 'test_loglik_unnormalized', 'test_rmse_unnormalized'

results, fields = read_regression_classification(fs, models_names, _ALL_REGRESSION_DATATSETS, 'regression')
# Out:
# linear energy 10
# variationally_sparse_gp energy 10
# deep_gp_doubly_stochastic energy 10
# svm energy 10
# knn energy 10
# gradient_boosting_machine energy 10
# adaboost energy 10
# mlp energy 10
# linear yacht 10
# variationally_sparse_gp yacht 10
# deep_gp_doubly_stochastic yacht 10
# svm yacht 10
# knn yacht 10
# gradient_boosting_machine yacht 10
# adaboost yacht 10
# mlp yacht 10
# linear boston 10
# variationally_sparse_gp boston 11
# deep_gp_doubly_stochastic boston 10
# svm boston 10
# knn boston 10
# gradient_boosting_machine boston 10
# adaboost boston 10
# mlp boston 10
# linear winered 10
# variationally_sparse_gp winered 10
# deep_gp_doubly_stochastic winered 10
# svm winered 10
# knn winered 10
# gradient_boosting_machine winered 10
# adaboost winered 10
# mlp winered 10
# linear protein 10
# variationally_sparse_gp protein 10
# deep_gp_doubly_stochastic protein 10
# svm protein 10
# knn protein 10
# gradient_boosting_machine protein 10
# adaboost protein 10
# mlp protein 10
# linear power 10
# variationally_sparse_gp power 10
# deep_gp_doubly_stochastic power 10
# svm power 10
# knn power 10
# gradient_boosting_machine power 10
# adaboost power 10
# mlp power 10
# linear concrete 10
# variationally_sparse_gp concrete 10
# deep_gp_doubly_stochastic concrete 9
# svm concrete 10
# knn concrete 10
# gradient_boosting_machine concrete 10
# adaboost concrete 10
# mlp concrete 10
# linear winewhite 10
# variationally_sparse_gp winewhite 10
# deep_gp_doubly_stochastic winewhite 10
# svm winewhite 10
# knn winewhite 10
# gradient_boosting_machine winewhite 10
# adaboost winewhite 10
# mlp winewhite 10
# linear naval 10
# variationally_sparse_gp naval 10
# deep_gp_doubly_stochastic naval 9
# svm naval 10
# knn naval 10
# gradient_boosting_machine naval 10
# adaboost naval 10
# mlp naval 10
# /vol/sml/hrs13/environments/py35cpu/lib/python3.5/site-packages/ipykernel_launcher.py:62: RuntimeWarning: Mean of empty slice
# /vol/sml/hrs13/environments/py35cpu/lib/python3.5/site-packages/numpy/lib/function_base.py:4033: RuntimeWarning: All-NaN slice encountered
#   r = func(a, **kwargs)

# %%
print('normalised test loglikelihood')
display(HTML(pandas.DataFrame(results['test_loglik']['table'], columns=fields).to_html(index=False)))
# print(pandas.DataFrame(results['test_loglik']['table'], columns=fields).to_latex())

print('unnormalized test loglikelihood')
display(HTML(pandas.DataFrame(results['test_loglik_unnormalized']['table'], columns=fields).to_html(index=False)))


print('normalised test rmse')
display(HTML(pandas.DataFrame(results['test_rmse']['table'], columns=fields).to_html(index=False)))

print('normalised test rmse')
display(HTML(pandas.DataFrame(results['test_rmse_unnormalized']['table'], columns=fields).to_html(index=False)))
# Out:
# normalised test loglikelihood
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>dataset</th>
#       <th>N</th>
#       <th>D</th>
#       <th>lin</th>
#       <th>SVGP</th>
#       <th>SVGP_mb</th>
#       <th>DGP</th>
#       <th>svm</th>
#       <th>knn</th>
#       <th>gbm</th>
#       <th>ab</th>
#       <th>mlp</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>energy</td>
#       <td>768</td>
#       <td>8</td>
#       <td>-0.220(0.114)</td>
#       <td>1.227(0.042)</td>
#       <td></td>
#       <td>1.590(0.106)</td>
#       <td>0.038(0.159)</td>
#       <td>-0.022(0.253)</td>
#       <td>1.603(0.154)</td>
#       <td>0.237(0.034)</td>
#       <td>0.121(0.153)</td>
#     </tr>
#     <tr>
#       <td>yacht</td>
#       <td>308</td>
#       <td>6</td>
#       <td>-0.929(0.083)</td>
#       <td>1.943(0.141)</td>
#       <td></td>
#       <td>2.259(0.134)</td>
#       <td>-0.614(0.286)</td>
#       <td>-1.155(0.320)</td>
#       <td>-0.589(2.235)</td>
#       <td>0.799(0.351)</td>
#       <td>-0.090(0.318)</td>
#     </tr>
#     <tr>
#       <td>boston</td>
#       <td>506</td>
#       <td>13</td>
#       <td>-0.644(0.066)</td>
#       <td>-0.180(0.064)</td>
#       <td></td>
#       <td>-0.190(0.052)</td>
#       <td>-0.157(0.083)</td>
#       <td>-0.467(0.134)</td>
#       <td>-0.642(0.243)</td>
#       <td>-0.368(0.099)</td>
#       <td>-0.228(0.111)</td>
#     </tr>
#     <tr>
#       <td>winered</td>
#       <td>1599</td>
#       <td>11</td>
#       <td>-1.208(0.060)</td>
#       <td>-1.163(0.065)</td>
#       <td></td>
#       <td>-1.168(0.064)</td>
#       <td>-1.174(0.095)</td>
#       <td>-1.280(0.121)</td>
#       <td>-1.206(0.100)</td>
#       <td>-1.176(0.082)</td>
#       <td>-1.189(0.098)</td>
#     </tr>
#     <tr>
#       <td>protein</td>
#       <td>45730</td>
#       <td>9</td>
#       <td>-1.257(0.005)</td>
#       <td>-1.090(0.008)</td>
#       <td></td>
#       <td>-1.035(0.009)</td>
#       <td>-1.150(0.011)</td>
#       <td>-1.013(0.018)</td>
#       <td>-1.156(0.009)</td>
#       <td>-1.359(0.014)</td>
#       <td>-1.092(0.014)</td>
#     </tr>
#     <tr>
#       <td>power</td>
#       <td>9568</td>
#       <td>4</td>
#       <td>-0.098(0.031)</td>
#       <td>0.038(0.036)</td>
#       <td></td>
#       <td>0.047(0.037)</td>
#       <td>0.034(0.038)</td>
#       <td>0.046(0.056)</td>
#       <td>0.066(0.042)</td>
#       <td>-0.309(0.037)</td>
#       <td>0.002(0.034)</td>
#     </tr>
#     <tr>
#       <td>concrete</td>
#       <td>1030</td>
#       <td>8</td>
#       <td>-0.953(0.052)</td>
#       <td>-0.353(0.054)</td>
#       <td></td>
#       <td>-0.359(0.055)</td>
#       <td>-0.558(0.107)</td>
#       <td>-0.828(0.101)</td>
#       <td>-0.440(0.162)</td>
#       <td>-0.678(0.086)</td>
#       <td>-0.433(0.122)</td>
#     </tr>
#     <tr>
#       <td>winewhite</td>
#       <td>4898</td>
#       <td>12</td>
#       <td>-1.254(0.039)</td>
#       <td>-1.167(0.027)</td>
#       <td></td>
#       <td>-1.164(0.025)</td>
#       <td>-1.161(0.031)</td>
#       <td>-1.230(0.040)</td>
#       <td>-1.161(0.031)</td>
#       <td>-1.228(0.031)</td>
#       <td>-1.170(0.036)</td>
#     </tr>
#     <tr>
#       <td>naval</td>
#       <td>11934</td>
#       <td>12</td>
#       <td>-0.489(0.017)</td>
#       <td>5.135(0.015)</td>
#       <td></td>
#       <td>2.527(0.224)</td>
#       <td>0.120(0.028)</td>
#       <td>0.740(0.109)</td>
#       <td>-0.088(0.030)</td>
#       <td>-1.297(0.019)</td>
#       <td>1.080(0.154)</td>
#     </tr>
#     <tr>
#       <td>avg</td>
#       <td></td>
#       <td></td>
#       <td>-0.784</td>
#       <td>0.488</td>
#       <td>nan</td>
#       <td>0.279</td>
#       <td>-0.514</td>
#       <td>-0.579</td>
#       <td>-0.401</td>
#       <td>-0.598</td>
#       <td>-0.333</td>
#     </tr>
#     <tr>
#       <td>median</td>
#       <td></td>
#       <td></td>
#       <td>-0.929</td>
#       <td>-0.180</td>
#       <td>nan</td>
#       <td>-0.190</td>
#       <td>-0.558</td>
#       <td>-0.828</td>
#       <td>-0.589</td>
#       <td>-0.678</td>
#       <td>-0.228</td>
#     </tr>
#     <tr>
#       <td>avg rank</td>
#       <td></td>
#       <td></td>
#       <td>1.556</td>
#       <td>6.667</td>
#       <td>9.000</td>
#       <td>6.889</td>
#       <td>4.889</td>
#       <td>3.333</td>
#       <td>4.778</td>
#       <td>3.222</td>
#       <td>4.667</td>
#     </tr>
#   </tbody>
# </table>
# unnormalized test loglikelihood
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>dataset</th>
#       <th>N</th>
#       <th>D</th>
#       <th>lin</th>
#       <th>SVGP</th>
#       <th>SVGP_mb</th>
#       <th>DGP</th>
#       <th>svm</th>
#       <th>knn</th>
#       <th>gbm</th>
#       <th>ab</th>
#       <th>mlp</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>energy</td>
#       <td>768</td>
#       <td>8</td>
#       <td>-2.531(0.114)</td>
#       <td>-1.084(0.042)</td>
#       <td></td>
#       <td>-0.721(0.106)</td>
#       <td>-2.273(0.159)</td>
#       <td>-2.333(0.253)</td>
#       <td>-0.708(0.154)</td>
#       <td>-2.074(0.034)</td>
#       <td>-2.190(0.153)</td>
#     </tr>
#     <tr>
#       <td>yacht</td>
#       <td>308</td>
#       <td>6</td>
#       <td>-3.646(0.083)</td>
#       <td>-0.774(0.141)</td>
#       <td></td>
#       <td>-0.458(0.134)</td>
#       <td>-3.331(0.286)</td>
#       <td>-3.872(0.320)</td>
#       <td>-3.306(2.235)</td>
#       <td>-1.918(0.351)</td>
#       <td>-2.807(0.318)</td>
#     </tr>
#     <tr>
#       <td>boston</td>
#       <td>506</td>
#       <td>13</td>
#       <td>-2.862(0.066)</td>
#       <td>-2.398(0.064)</td>
#       <td></td>
#       <td>-2.408(0.052)</td>
#       <td>-2.375(0.083)</td>
#       <td>-2.685(0.134)</td>
#       <td>-2.860(0.243)</td>
#       <td>-2.586(0.099)</td>
#       <td>-2.446(0.111)</td>
#     </tr>
#     <tr>
#       <td>winered</td>
#       <td>1599</td>
#       <td>11</td>
#       <td>-0.994(0.060)</td>
#       <td>-0.949(0.065)</td>
#       <td></td>
#       <td>-0.954(0.064)</td>
#       <td>-0.960(0.095)</td>
#       <td>-1.066(0.121)</td>
#       <td>-0.991(0.100)</td>
#       <td>-0.962(0.082)</td>
#       <td>-0.975(0.098)</td>
#     </tr>
#     <tr>
#       <td>protein</td>
#       <td>45730</td>
#       <td>9</td>
#       <td>-3.068(0.005)</td>
#       <td>-2.901(0.008)</td>
#       <td></td>
#       <td>-2.846(0.009)</td>
#       <td>-2.962(0.011)</td>
#       <td>-2.824(0.018)</td>
#       <td>-2.967(0.009)</td>
#       <td>-3.170(0.014)</td>
#       <td>-2.903(0.014)</td>
#     </tr>
#     <tr>
#       <td>power</td>
#       <td>9568</td>
#       <td>4</td>
#       <td>-2.935(0.031)</td>
#       <td>-2.799(0.036)</td>
#       <td></td>
#       <td>-2.790(0.037)</td>
#       <td>-2.803(0.038)</td>
#       <td>-2.791(0.056)</td>
#       <td>-2.771(0.042)</td>
#       <td>-3.146(0.037)</td>
#       <td>-2.835(0.034)</td>
#     </tr>
#     <tr>
#       <td>concrete</td>
#       <td>1030</td>
#       <td>8</td>
#       <td>-3.768(0.052)</td>
#       <td>-3.168(0.054)</td>
#       <td></td>
#       <td>-3.175(0.055)</td>
#       <td>-3.373(0.107)</td>
#       <td>-3.643(0.101)</td>
#       <td>-3.256(0.162)</td>
#       <td>-3.494(0.086)</td>
#       <td>-3.248(0.122)</td>
#     </tr>
#     <tr>
#       <td>winewhite</td>
#       <td>4898</td>
#       <td>12</td>
#       <td>-1.133(0.039)</td>
#       <td>-1.045(0.027)</td>
#       <td></td>
#       <td>-1.043(0.025)</td>
#       <td>-1.039(0.031)</td>
#       <td>-1.108(0.040)</td>
#       <td>-1.040(0.031)</td>
#       <td>-1.106(0.031)</td>
#       <td>-1.049(0.036)</td>
#     </tr>
#     <tr>
#       <td>naval</td>
#       <td>11934</td>
#       <td>12</td>
#       <td>3.730(0.017)</td>
#       <td>9.353(0.015)</td>
#       <td></td>
#       <td>6.746(0.224)</td>
#       <td>4.338(0.028)</td>
#       <td>4.958(0.109)</td>
#       <td>4.130(0.030)</td>
#       <td>2.921(0.019)</td>
#       <td>5.298(0.154)</td>
#     </tr>
#   </tbody>
# </table>
# normalised test rmse
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>dataset</th>
#       <th>N</th>
#       <th>D</th>
#       <th>lin</th>
#       <th>SVGP</th>
#       <th>SVGP_mb</th>
#       <th>DGP</th>
#       <th>svm</th>
#       <th>knn</th>
#       <th>gbm</th>
#       <th>ab</th>
#       <th>mlp</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>energy</td>
#       <td>768</td>
#       <td>8</td>
#       <td>0.300(0.034)</td>
#       <td>0.064(0.005)</td>
#       <td></td>
#       <td>0.048(0.006)</td>
#       <td>0.227(0.027)</td>
#       <td>0.219(0.029)</td>
#       <td>0.047(0.005)</td>
#       <td>0.190(0.006)</td>
#       <td>0.210(0.033)</td>
#     </tr>
#     <tr>
#       <td>yacht</td>
#       <td>308</td>
#       <td>6</td>
#       <td>0.608(0.048)</td>
#       <td>0.043(0.014)</td>
#       <td></td>
#       <td>0.031(0.013)</td>
#       <td>0.419(0.092)</td>
#       <td>0.670(0.138)</td>
#       <td>0.044(0.014)</td>
#       <td>0.103(0.023)</td>
#       <td>0.244(0.051)</td>
#     </tr>
#     <tr>
#       <td>boston</td>
#       <td>506</td>
#       <td>13</td>
#       <td>0.444(0.044)</td>
#       <td>0.282(0.029)</td>
#       <td></td>
#       <td>0.286(0.025)</td>
#       <td>0.267(0.037)</td>
#       <td>0.380(0.059)</td>
#       <td>0.283(0.020)</td>
#       <td>0.344(0.028)</td>
#       <td>0.298(0.026)</td>
#     </tr>
#     <tr>
#       <td>winered</td>
#       <td>1599</td>
#       <td>11</td>
#       <td>0.808(0.046)</td>
#       <td>0.777(0.051)</td>
#       <td></td>
#       <td>0.780(0.051)</td>
#       <td>0.768(0.055)</td>
#       <td>0.825(0.063)</td>
#       <td>0.761(0.046)</td>
#       <td>0.778(0.054)</td>
#       <td>0.775(0.056)</td>
#     </tr>
#     <tr>
#       <td>protein</td>
#       <td>45730</td>
#       <td>9</td>
#       <td>0.850(0.004)</td>
#       <td>0.719(0.007)</td>
#       <td></td>
#       <td>0.681(0.007)</td>
#       <td>0.764(0.008)</td>
#       <td>0.623(0.007)</td>
#       <td>0.768(0.007)</td>
#       <td>0.941(0.013)</td>
#       <td>0.721(0.010)</td>
#     </tr>
#     <tr>
#       <td>power</td>
#       <td>9568</td>
#       <td>4</td>
#       <td>0.267(0.008)</td>
#       <td>0.232(0.008)</td>
#       <td></td>
#       <td>0.230(0.009)</td>
#       <td>0.234(0.009)</td>
#       <td>0.219(0.008)</td>
#       <td>0.226(0.008)</td>
#       <td>0.329(0.012)</td>
#       <td>0.241(0.008)</td>
#     </tr>
#     <tr>
#       <td>concrete</td>
#       <td>1030</td>
#       <td>8</td>
#       <td>0.626(0.031)</td>
#       <td>0.357(0.024)</td>
#       <td></td>
#       <td>0.357(0.022)</td>
#       <td>0.405(0.030)</td>
#       <td>0.519(0.031)</td>
#       <td>0.323(0.026)</td>
#       <td>0.468(0.030)</td>
#       <td>0.347(0.027)</td>
#     </tr>
#     <tr>
#       <td>winewhite</td>
#       <td>4898</td>
#       <td>12</td>
#       <td>0.847(0.033)</td>
#       <td>0.778(0.024)</td>
#       <td></td>
#       <td>0.776(0.022)</td>
#       <td>0.768(0.021)</td>
#       <td>0.788(0.020)</td>
#       <td>0.768(0.021)</td>
#       <td>0.825(0.025)</td>
#       <td>0.778(0.026)</td>
#     </tr>
#     <tr>
#       <td>naval</td>
#       <td>11934</td>
#       <td>12</td>
#       <td>0.394(0.007)</td>
#       <td>0.001(0.000)</td>
#       <td></td>
#       <td>0.017(0.007)</td>
#       <td>0.215(0.006)</td>
#       <td>0.104(0.006)</td>
#       <td>0.263(0.007)</td>
#       <td>0.885(0.017)</td>
#       <td>0.083(0.014)</td>
#     </tr>
#     <tr>
#       <td>avg</td>
#       <td></td>
#       <td></td>
#       <td>0.572</td>
#       <td>0.362</td>
#       <td>nan</td>
#       <td>0.356</td>
#       <td>0.452</td>
#       <td>0.483</td>
#       <td>0.387</td>
#       <td>0.540</td>
#       <td>0.411</td>
#     </tr>
#     <tr>
#       <td>median</td>
#       <td></td>
#       <td></td>
#       <td>0.608</td>
#       <td>0.282</td>
#       <td>nan</td>
#       <td>0.286</td>
#       <td>0.405</td>
#       <td>0.519</td>
#       <td>0.283</td>
#       <td>0.468</td>
#       <td>0.298</td>
#     </tr>
#     <tr>
#       <td>avg rank</td>
#       <td></td>
#       <td></td>
#       <td>7.444</td>
#       <td>3.111</td>
#       <td>9.000</td>
#       <td>2.889</td>
#       <td>4.111</td>
#       <td>5.333</td>
#       <td>2.778</td>
#       <td>6.222</td>
#       <td>4.111</td>
#     </tr>
#   </tbody>
# </table>
# normalised test rmse
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>dataset</th>
#       <th>N</th>
#       <th>D</th>
#       <th>lin</th>
#       <th>SVGP</th>
#       <th>SVGP_mb</th>
#       <th>DGP</th>
#       <th>svm</th>
#       <th>knn</th>
#       <th>gbm</th>
#       <th>ab</th>
#       <th>mlp</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>energy</td>
#       <td>768</td>
#       <td>8</td>
#       <td>3.029(0.342)</td>
#       <td>0.650(0.049)</td>
#       <td></td>
#       <td>0.486(0.060)</td>
#       <td>2.290(0.274)</td>
#       <td>2.204(0.295)</td>
#       <td>0.477(0.051)</td>
#       <td>1.921(0.063)</td>
#       <td>2.115(0.329)</td>
#     </tr>
#     <tr>
#       <td>yacht</td>
#       <td>308</td>
#       <td>6</td>
#       <td>9.208(0.721)</td>
#       <td>0.655(0.217)</td>
#       <td></td>
#       <td>0.476(0.198)</td>
#       <td>6.339(1.385)</td>
#       <td>10.136(2.090)</td>
#       <td>0.673(0.209)</td>
#       <td>1.553(0.346)</td>
#       <td>3.687(0.767)</td>
#     </tr>
#     <tr>
#       <td>boston</td>
#       <td>506</td>
#       <td>13</td>
#       <td>4.076(0.406)</td>
#       <td>2.588(0.262)</td>
#       <td></td>
#       <td>2.625(0.232)</td>
#       <td>2.455(0.336)</td>
#       <td>3.487(0.538)</td>
#       <td>2.598(0.183)</td>
#       <td>3.162(0.255)</td>
#       <td>2.735(0.241)</td>
#     </tr>
#     <tr>
#       <td>winered</td>
#       <td>1599</td>
#       <td>11</td>
#       <td>0.652(0.037)</td>
#       <td>0.627(0.041)</td>
#       <td></td>
#       <td>0.630(0.041)</td>
#       <td>0.620(0.044)</td>
#       <td>0.666(0.051)</td>
#       <td>0.615(0.037)</td>
#       <td>0.628(0.044)</td>
#       <td>0.626(0.045)</td>
#     </tr>
#     <tr>
#       <td>protein</td>
#       <td>45730</td>
#       <td>9</td>
#       <td>5.201(0.027)</td>
#       <td>4.401(0.040)</td>
#       <td></td>
#       <td>4.169(0.041)</td>
#       <td>4.676(0.049)</td>
#       <td>3.812(0.041)</td>
#       <td>4.701(0.041)</td>
#       <td>5.758(0.078)</td>
#       <td>4.410(0.062)</td>
#     </tr>
#     <tr>
#       <td>power</td>
#       <td>9568</td>
#       <td>4</td>
#       <td>4.553(0.142)</td>
#       <td>3.967(0.145)</td>
#       <td></td>
#       <td>3.927(0.156)</td>
#       <td>3.987(0.146)</td>
#       <td>3.731(0.129)</td>
#       <td>3.856(0.145)</td>
#       <td>5.612(0.205)</td>
#       <td>4.115(0.139)</td>
#     </tr>
#     <tr>
#       <td>concrete</td>
#       <td>1030</td>
#       <td>8</td>
#       <td>10.458(0.518)</td>
#       <td>5.965(0.393)</td>
#       <td></td>
#       <td>5.955(0.366)</td>
#       <td>6.767(0.495)</td>
#       <td>8.672(0.521)</td>
#       <td>5.390(0.427)</td>
#       <td>7.813(0.508)</td>
#       <td>5.787(0.451)</td>
#     </tr>
#     <tr>
#       <td>winewhite</td>
#       <td>4898</td>
#       <td>12</td>
#       <td>0.750(0.029)</td>
#       <td>0.689(0.021)</td>
#       <td></td>
#       <td>0.687(0.020)</td>
#       <td>0.680(0.018)</td>
#       <td>0.698(0.018)</td>
#       <td>0.680(0.018)</td>
#       <td>0.731(0.022)</td>
#       <td>0.689(0.023)</td>
#     </tr>
#     <tr>
#       <td>naval</td>
#       <td>11934</td>
#       <td>12</td>
#       <td>0.006(0.000)</td>
#       <td>0.000(0.000)</td>
#       <td></td>
#       <td>0.000(0.000)</td>
#       <td>0.003(0.000)</td>
#       <td>0.002(0.000)</td>
#       <td>0.004(0.000)</td>
#       <td>0.013(0.000)</td>
#       <td>0.001(0.000)</td>
#     </tr>
#   </tbody>
# </table>

# %%
fs = ['test_loglik', 'test_acc']
results, fields = read_regression_classification(fs, models_names, classification_datasets, 'classification')
# Out:
# linear abalone 20
# variationally_sparse_gp abalone 10
# deep_gp_doubly_stochastic abalone 10
# svm abalone 10
# knn abalone 10
# gradient_boosting_machine abalone 10
# adaboost abalone 10
# mlp abalone 10
# linear acute-inflammation 20
# variationally_sparse_gp acute-inflammation 10
# deep_gp_doubly_stochastic acute-inflammation 10
# svm acute-inflammation 10
# knn acute-inflammation 10
# gradient_boosting_machine acute-inflammation 10
# adaboost acute-inflammation 10
# mlp acute-inflammation 10
# linear acute-nephritis 20
# variationally_sparse_gp acute-nephritis 10
# deep_gp_doubly_stochastic acute-nephritis 10
# svm acute-nephritis 10
# knn acute-nephritis 10
# gradient_boosting_machine acute-nephritis 10
# adaboost acute-nephritis 10
# mlp acute-nephritis 10
# linear adult 20
# svm adult 10
# knn adult 10
# gradient_boosting_machine adult 10
# adaboost adult 10
# mlp adult 10
# linear annealing 20
# variationally_sparse_gp annealing 10
# deep_gp_doubly_stochastic annealing 10
# svm annealing 10
# knn annealing 10
# gradient_boosting_machine annealing 10
# adaboost annealing 10
# mlp annealing 10
# linear arrhythmia 20
# variationally_sparse_gp arrhythmia 10
# deep_gp_doubly_stochastic arrhythmia 5
# svm arrhythmia 10
# knn arrhythmia 10
# gradient_boosting_machine arrhythmia 10
# adaboost arrhythmia 10
# mlp arrhythmia 10
# linear audiology-std 20
# variationally_sparse_gp audiology-std 10
# deep_gp_doubly_stochastic audiology-std 10
# svm audiology-std 10
# knn audiology-std 10
# gradient_boosting_machine audiology-std 10
# adaboost audiology-std 10
# mlp audiology-std 10
# linear balance-scale 20
# variationally_sparse_gp balance-scale 10
# deep_gp_doubly_stochastic balance-scale 10
# svm balance-scale 10
# knn balance-scale 10
# gradient_boosting_machine balance-scale 10
# adaboost balance-scale 10
# mlp balance-scale 10
# linear balloons 20
# deep_gp_doubly_stochastic balloons 10
# svm balloons 10
# knn balloons 10
# gradient_boosting_machine balloons 10
# adaboost balloons 10
# mlp balloons 10
# linear bank 20
# variationally_sparse_gp bank 10
# deep_gp_doubly_stochastic bank 10
# svm bank 10
# knn bank 10
# gradient_boosting_machine bank 10
# adaboost bank 10
# mlp bank 10
# linear blood 20
# variationally_sparse_gp blood 9
# deep_gp_doubly_stochastic blood 10
# svm blood 10
# knn blood 10
# gradient_boosting_machine blood 10
# adaboost blood 10
# mlp blood 10
# linear breast-cancer 20
# variationally_sparse_gp breast-cancer 10
# deep_gp_doubly_stochastic breast-cancer 10
# svm breast-cancer 10
# knn breast-cancer 10
# gradient_boosting_machine breast-cancer 10
# adaboost breast-cancer 10
# mlp breast-cancer 10
# linear breast-cancer-wisc 20
# variationally_sparse_gp breast-cancer-wisc 3
# deep_gp_doubly_stochastic breast-cancer-wisc 10
# svm breast-cancer-wisc 10
# knn breast-cancer-wisc 10
# gradient_boosting_machine breast-cancer-wisc 10
# adaboost breast-cancer-wisc 10
# mlp breast-cancer-wisc 10
# linear breast-cancer-wisc-diag 20
# variationally_sparse_gp breast-cancer-wisc-diag 7
# deep_gp_doubly_stochastic breast-cancer-wisc-diag 10
# svm breast-cancer-wisc-diag 10
# knn breast-cancer-wisc-diag 10
# gradient_boosting_machine breast-cancer-wisc-diag 10
# adaboost breast-cancer-wisc-diag 10
# mlp breast-cancer-wisc-diag 10
# linear breast-cancer-wisc-prog 20
# variationally_sparse_gp breast-cancer-wisc-prog 9
# deep_gp_doubly_stochastic breast-cancer-wisc-prog 10
# svm breast-cancer-wisc-prog 10
# knn breast-cancer-wisc-prog 10
# gradient_boosting_machine breast-cancer-wisc-prog 10
# adaboost breast-cancer-wisc-prog 10
# mlp breast-cancer-wisc-prog 10
# linear breast-tissue 20
# deep_gp_doubly_stochastic breast-tissue 10
# svm breast-tissue 10
# knn breast-tissue 10
# gradient_boosting_machine breast-tissue 10
# adaboost breast-tissue 10
# mlp breast-tissue 10
# linear car 20
# variationally_sparse_gp car 9
# deep_gp_doubly_stochastic car 10
# svm car 10
# knn car 10
# gradient_boosting_machine car 10
# adaboost car 10
# mlp car 10
# linear cardiotocography-10clases 20
# variationally_sparse_gp cardiotocography-10clases 10
# deep_gp_doubly_stochastic cardiotocography-10clases 10
# svm cardiotocography-10clases 10
# knn cardiotocography-10clases 10
# gradient_boosting_machine cardiotocography-10clases 10
# adaboost cardiotocography-10clases 10
# mlp cardiotocography-10clases 10
# linear cardiotocography-3clases 20
# variationally_sparse_gp cardiotocography-3clases 10
# deep_gp_doubly_stochastic cardiotocography-3clases 10
# svm cardiotocography-3clases 10
# knn cardiotocography-3clases 10
# gradient_boosting_machine cardiotocography-3clases 10
# adaboost cardiotocography-3clases 10
# mlp cardiotocography-3clases 10
# linear chess-krvk 20
# svm chess-krvk 10
# knn chess-krvk 10
# gradient_boosting_machine chess-krvk 10
# adaboost chess-krvk 10
# mlp chess-krvk 10
# linear chess-krvkp 20
# variationally_sparse_gp chess-krvkp 10
# deep_gp_doubly_stochastic chess-krvkp 8
# svm chess-krvkp 10
# knn chess-krvkp 10
# gradient_boosting_machine chess-krvkp 10
# adaboost chess-krvkp 10
# mlp chess-krvkp 10
# linear congressional-voting 20
# variationally_sparse_gp congressional-voting 10
# deep_gp_doubly_stochastic congressional-voting 10
# svm congressional-voting 10
# knn congressional-voting 10
# gradient_boosting_machine congressional-voting 10
# adaboost congressional-voting 10
# mlp congressional-voting 10
# linear conn-bench-sonar-mines-rocks 20
# variationally_sparse_gp conn-bench-sonar-mines-rocks 10
# deep_gp_doubly_stochastic conn-bench-sonar-mines-rocks 10
# svm conn-bench-sonar-mines-rocks 10
# knn conn-bench-sonar-mines-rocks 10
# gradient_boosting_machine conn-bench-sonar-mines-rocks 10
# adaboost conn-bench-sonar-mines-rocks 10
# mlp conn-bench-sonar-mines-rocks 10
# linear conn-bench-vowel-deterding 20
# variationally_sparse_gp conn-bench-vowel-deterding 10
# deep_gp_doubly_stochastic conn-bench-vowel-deterding 10
# svm conn-bench-vowel-deterding 10
# knn conn-bench-vowel-deterding 10
# gradient_boosting_machine conn-bench-vowel-deterding 10
# adaboost conn-bench-vowel-deterding 10
# mlp conn-bench-vowel-deterding 10
# linear connect-4 20
# svm connect-4 10
# knn connect-4 10
# gradient_boosting_machine connect-4 10
# adaboost connect-4 10
# mlp connect-4 10
# linear contrac 20
# variationally_sparse_gp contrac 10
# deep_gp_doubly_stochastic contrac 10
# svm contrac 10
# knn contrac 10
# gradient_boosting_machine contrac 10
# adaboost contrac 10
# mlp contrac 10
# linear credit-approval 20
# variationally_sparse_gp credit-approval 10
# deep_gp_doubly_stochastic credit-approval 10
# svm credit-approval 10
# knn credit-approval 10
# gradient_boosting_machine credit-approval 10
# adaboost credit-approval 10
# mlp credit-approval 10
# linear cylinder-bands 20
# variationally_sparse_gp cylinder-bands 10
# deep_gp_doubly_stochastic cylinder-bands 10
# svm cylinder-bands 10
# knn cylinder-bands 10
# gradient_boosting_machine cylinder-bands 10
# adaboost cylinder-bands 10
# mlp cylinder-bands 10
# linear dermatology 20
# variationally_sparse_gp dermatology 10
# deep_gp_doubly_stochastic dermatology 10
# svm dermatology 10
# knn dermatology 10
# gradient_boosting_machine dermatology 10
# adaboost dermatology 10
# mlp dermatology 10
# linear echocardiogram 20
# variationally_sparse_gp echocardiogram 10
# deep_gp_doubly_stochastic echocardiogram 10
# svm echocardiogram 10
# knn echocardiogram 10
# gradient_boosting_machine echocardiogram 10
# adaboost echocardiogram 10
# mlp echocardiogram 10
# linear ecoli 20
# variationally_sparse_gp ecoli 10
# deep_gp_doubly_stochastic ecoli 10
# svm ecoli 10
# knn ecoli 10
# gradient_boosting_machine ecoli 10
# adaboost ecoli 10
# mlp ecoli 10
# linear energy-y1 20
# variationally_sparse_gp energy-y1 10
# deep_gp_doubly_stochastic energy-y1 10
# svm energy-y1 10
# knn energy-y1 10
# gradient_boosting_machine energy-y1 10
# adaboost energy-y1 10
# mlp energy-y1 10
# linear energy-y2 20
# variationally_sparse_gp energy-y2 10
# deep_gp_doubly_stochastic energy-y2 10
# svm energy-y2 10
# knn energy-y2 10
# gradient_boosting_machine energy-y2 10
# adaboost energy-y2 10
# mlp energy-y2 10
# linear fertility 20
# deep_gp_doubly_stochastic fertility 10
# svm fertility 10
# knn fertility 10
# gradient_boosting_machine fertility 10
# adaboost fertility 10
# mlp fertility 10
# linear flags 20
# variationally_sparse_gp flags 10
# deep_gp_doubly_stochastic flags 10
# svm flags 10
# knn flags 10
# gradient_boosting_machine flags 10
# adaboost flags 10
# mlp flags 10
# linear glass 20
# variationally_sparse_gp glass 10
# deep_gp_doubly_stochastic glass 10
# svm glass 10
# knn glass 10
# gradient_boosting_machine glass 10
# adaboost glass 10
# mlp glass 10
# linear haberman-survival 20
# variationally_sparse_gp haberman-survival 10
# deep_gp_doubly_stochastic haberman-survival 10
# svm haberman-survival 10
# knn haberman-survival 10
# gradient_boosting_machine haberman-survival 10
# adaboost haberman-survival 10
# mlp haberman-survival 10
# linear hayes-roth 20
# variationally_sparse_gp hayes-roth 10
# deep_gp_doubly_stochastic hayes-roth 10
# svm hayes-roth 10
# knn hayes-roth 10
# gradient_boosting_machine hayes-roth 10
# adaboost hayes-roth 10
# mlp hayes-roth 10
# linear heart-cleveland 20
# variationally_sparse_gp heart-cleveland 10
# deep_gp_doubly_stochastic heart-cleveland 10
# svm heart-cleveland 10
# knn heart-cleveland 10
# gradient_boosting_machine heart-cleveland 10
# adaboost heart-cleveland 10
# mlp heart-cleveland 10
# linear heart-hungarian 20
# variationally_sparse_gp heart-hungarian 10
# deep_gp_doubly_stochastic heart-hungarian 10
# svm heart-hungarian 10
# knn heart-hungarian 10
# gradient_boosting_machine heart-hungarian 10
# adaboost heart-hungarian 10
# mlp heart-hungarian 10
# linear heart-switzerland 20
# variationally_sparse_gp heart-switzerland 10
# deep_gp_doubly_stochastic heart-switzerland 10
# svm heart-switzerland 10
# knn heart-switzerland 10
# gradient_boosting_machine heart-switzerland 10
# adaboost heart-switzerland 10
# mlp heart-switzerland 10
# linear heart-va 20
# variationally_sparse_gp heart-va 10
# deep_gp_doubly_stochastic heart-va 10
# svm heart-va 10
# knn heart-va 10
# gradient_boosting_machine heart-va 10
# adaboost heart-va 10
# mlp heart-va 10
# linear hepatitis 20
# variationally_sparse_gp hepatitis 10
# deep_gp_doubly_stochastic hepatitis 10
# svm hepatitis 10
# knn hepatitis 10
# gradient_boosting_machine hepatitis 10
# adaboost hepatitis 10
# mlp hepatitis 10
# linear hill-valley 20
# variationally_sparse_gp hill-valley 10
# deep_gp_doubly_stochastic hill-valley 4
# svm hill-valley 10
# knn hill-valley 10
# gradient_boosting_machine hill-valley 10
# adaboost hill-valley 10
# mlp hill-valley 10
# linear horse-colic 20
# variationally_sparse_gp horse-colic 10
# deep_gp_doubly_stochastic horse-colic 10
# svm horse-colic 10
# knn horse-colic 10
# gradient_boosting_machine horse-colic 10
# adaboost horse-colic 10
# mlp horse-colic 10
# linear ilpd-indian-liver 20
# variationally_sparse_gp ilpd-indian-liver 10
# deep_gp_doubly_stochastic ilpd-indian-liver 10
# svm ilpd-indian-liver 10
# knn ilpd-indian-liver 10
# gradient_boosting_machine ilpd-indian-liver 10
# adaboost ilpd-indian-liver 10
# mlp ilpd-indian-liver 10
# linear image-segmentation 20
# variationally_sparse_gp image-segmentation 10
# deep_gp_doubly_stochastic image-segmentation 10
# svm image-segmentation 10
# knn image-segmentation 10
# gradient_boosting_machine image-segmentation 10
# adaboost image-segmentation 10
# mlp image-segmentation 10
# linear ionosphere 20
# variationally_sparse_gp ionosphere 10
# deep_gp_doubly_stochastic ionosphere 10
# svm ionosphere 10
# knn ionosphere 10
# gradient_boosting_machine ionosphere 10
# adaboost ionosphere 10
# mlp ionosphere 10
# linear iris 20
# variationally_sparse_gp iris 10
# deep_gp_doubly_stochastic iris 10
# svm iris 10
# knn iris 10
# gradient_boosting_machine iris 10
# adaboost iris 10
# mlp iris 10
# linear led-display 20
# variationally_sparse_gp led-display 10
# deep_gp_doubly_stochastic led-display 10
# svm led-display 10
# knn led-display 10
# gradient_boosting_machine led-display 10
# adaboost led-display 10
# mlp led-display 10
# linear lenses 20
# deep_gp_doubly_stochastic lenses 10
# svm lenses 10
# knn lenses 10
# gradient_boosting_machine lenses 10
# adaboost lenses 10
# mlp lenses 10
# linear letter 20
# svm letter 10
# knn letter 10
# gradient_boosting_machine letter 10
# adaboost letter 10
# mlp letter 10
# linear libras 20
# variationally_sparse_gp libras 10
# deep_gp_doubly_stochastic libras 3
# svm libras 10
# knn libras 10
# gradient_boosting_machine libras 10
# adaboost libras 10
# mlp libras 10
# linear low-res-spect 20
# variationally_sparse_gp low-res-spect 10
# deep_gp_doubly_stochastic low-res-spect 5
# svm low-res-spect 10
# knn low-res-spect 10
# gradient_boosting_machine low-res-spect 10
# adaboost low-res-spect 10
# mlp low-res-spect 10
# linear lung-cancer 20
# deep_gp_doubly_stochastic lung-cancer 8
# svm lung-cancer 10
# knn lung-cancer 10
# gradient_boosting_machine lung-cancer 10
# adaboost lung-cancer 10
# mlp lung-cancer 10
# linear lymphography 20
# variationally_sparse_gp lymphography 10
# deep_gp_doubly_stochastic lymphography 10
# svm lymphography 10
# knn lymphography 10
# gradient_boosting_machine lymphography 10
# adaboost lymphography 10
# mlp lymphography 10
# linear magic 20
# deep_gp_doubly_stochastic magic 1
# svm magic 10
# knn magic 10
# gradient_boosting_machine magic 10
# adaboost magic 10
# mlp magic 10
# linear mammographic 20
# variationally_sparse_gp mammographic 10
# deep_gp_doubly_stochastic mammographic 10
# svm mammographic 10
# knn mammographic 10
# gradient_boosting_machine mammographic 10
# adaboost mammographic 10
# mlp mammographic 10
# linear miniboone 20
# svm miniboone 10
# knn miniboone 10
# gradient_boosting_machine miniboone 10
# adaboost miniboone 10
# mlp miniboone 10
# linear molec-biol-promoter 20
# deep_gp_doubly_stochastic molec-biol-promoter 10
# svm molec-biol-promoter 10
# knn molec-biol-promoter 10
# gradient_boosting_machine molec-biol-promoter 10
# adaboost molec-biol-promoter 10
# mlp molec-biol-promoter 10
# linear molec-biol-splice 20
# variationally_sparse_gp molec-biol-splice 10
# deep_gp_doubly_stochastic molec-biol-splice 1
# svm molec-biol-splice 10
# knn molec-biol-splice 10
# gradient_boosting_machine molec-biol-splice 10
# adaboost molec-biol-splice 10
# mlp molec-biol-splice 10
# linear monks-1 20
# variationally_sparse_gp monks-1 10
# deep_gp_doubly_stochastic monks-1 10
# svm monks-1 10
# knn monks-1 10
# gradient_boosting_machine monks-1 10
# adaboost monks-1 10
# mlp monks-1 10
# linear monks-2 20
# variationally_sparse_gp monks-2 10
# deep_gp_doubly_stochastic monks-2 10
# svm monks-2 10
# knn monks-2 10
# gradient_boosting_machine monks-2 10
# adaboost monks-2 10
# mlp monks-2 10
# linear monks-3 20
# variationally_sparse_gp monks-3 10
# deep_gp_doubly_stochastic monks-3 10
# svm monks-3 10
# knn monks-3 10
# gradient_boosting_machine monks-3 10
# adaboost monks-3 10
# mlp monks-3 10
# linear mushroom 20
# deep_gp_doubly_stochastic mushroom 2
# svm mushroom 10
# knn mushroom 10
# gradient_boosting_machine mushroom 10
# adaboost mushroom 10
# mlp mushroom 10
# linear musk-1 20
# variationally_sparse_gp musk-1 10
# deep_gp_doubly_stochastic musk-1 9
# svm musk-1 10
# knn musk-1 10
# gradient_boosting_machine musk-1 10
# adaboost musk-1 10
# mlp musk-1 10
# linear musk-2 20
# svm musk-2 10
# knn musk-2 10
# gradient_boosting_machine musk-2 10
# adaboost musk-2 10
# mlp musk-2 10
# linear nursery 20
# deep_gp_doubly_stochastic nursery 4
# svm nursery 10
# knn nursery 10
# gradient_boosting_machine nursery 10
# adaboost nursery 10
# mlp nursery 10
# linear oocytes_merluccius_nucleus_4d 20
# variationally_sparse_gp oocytes_merluccius_nucleus_4d 10
# deep_gp_doubly_stochastic oocytes_merluccius_nucleus_4d 10
# svm oocytes_merluccius_nucleus_4d 10
# knn oocytes_merluccius_nucleus_4d 10
# gradient_boosting_machine oocytes_merluccius_nucleus_4d 10
# adaboost oocytes_merluccius_nucleus_4d 10
# mlp oocytes_merluccius_nucleus_4d 10
# linear oocytes_merluccius_states_2f 20
# variationally_sparse_gp oocytes_merluccius_states_2f 10
# deep_gp_doubly_stochastic oocytes_merluccius_states_2f 10
# svm oocytes_merluccius_states_2f 10
# knn oocytes_merluccius_states_2f 10
# gradient_boosting_machine oocytes_merluccius_states_2f 10
# adaboost oocytes_merluccius_states_2f 10
# mlp oocytes_merluccius_states_2f 10
# linear oocytes_trisopterus_nucleus_2f 20
# variationally_sparse_gp oocytes_trisopterus_nucleus_2f 10
# deep_gp_doubly_stochastic oocytes_trisopterus_nucleus_2f 10
# svm oocytes_trisopterus_nucleus_2f 10
# knn oocytes_trisopterus_nucleus_2f 10
# gradient_boosting_machine oocytes_trisopterus_nucleus_2f 10
# adaboost oocytes_trisopterus_nucleus_2f 10
# mlp oocytes_trisopterus_nucleus_2f 10
# linear oocytes_trisopterus_states_5b 20
# variationally_sparse_gp oocytes_trisopterus_states_5b 10
# deep_gp_doubly_stochastic oocytes_trisopterus_states_5b 10
# svm oocytes_trisopterus_states_5b 10
# knn oocytes_trisopterus_states_5b 10
# gradient_boosting_machine oocytes_trisopterus_states_5b 10
# adaboost oocytes_trisopterus_states_5b 10
# mlp oocytes_trisopterus_states_5b 10
# linear optical 20
# deep_gp_doubly_stochastic optical 1
# svm optical 10
# knn optical 10
# gradient_boosting_machine optical 10
# adaboost optical 10
# mlp optical 10
# linear ozone 20
# variationally_sparse_gp ozone 10
# deep_gp_doubly_stochastic ozone 2
# svm ozone 10
# knn ozone 10
# gradient_boosting_machine ozone 10
# adaboost ozone 10
# mlp ozone 10
# linear page-blocks 20
# variationally_sparse_gp page-blocks 9
# deep_gp_doubly_stochastic page-blocks 10
# svm page-blocks 10
# knn page-blocks 10
# gradient_boosting_machine page-blocks 10
# adaboost page-blocks 10
# mlp page-blocks 10
# linear parkinsons 20
# variationally_sparse_gp parkinsons 8
# deep_gp_doubly_stochastic parkinsons 10
# svm parkinsons 10
# knn parkinsons 10
# gradient_boosting_machine parkinsons 10
# adaboost parkinsons 10
# mlp parkinsons 10
# linear pendigits 20
# deep_gp_doubly_stochastic pendigits 4
# svm pendigits 10
# knn pendigits 10
# gradient_boosting_machine pendigits 10
# adaboost pendigits 10
# mlp pendigits 9
# linear pima 20
# variationally_sparse_gp pima 8
# deep_gp_doubly_stochastic pima 10
# svm pima 10
# knn pima 10
# gradient_boosting_machine pima 10
# adaboost pima 10
# mlp pima 10
# linear pittsburg-bridges-MATERIAL 20
# deep_gp_doubly_stochastic pittsburg-bridges-MATERIAL 10
# svm pittsburg-bridges-MATERIAL 10
# knn pittsburg-bridges-MATERIAL 10
# gradient_boosting_machine pittsburg-bridges-MATERIAL 10
# adaboost pittsburg-bridges-MATERIAL 9
# mlp pittsburg-bridges-MATERIAL 10
# linear pittsburg-bridges-REL-L 20
# deep_gp_doubly_stochastic pittsburg-bridges-REL-L 10
# svm pittsburg-bridges-REL-L 10
# knn pittsburg-bridges-REL-L 10
# gradient_boosting_machine pittsburg-bridges-REL-L 10
# adaboost pittsburg-bridges-REL-L 10
# mlp pittsburg-bridges-REL-L 10
# linear pittsburg-bridges-SPAN 20
# deep_gp_doubly_stochastic pittsburg-bridges-SPAN 10
# svm pittsburg-bridges-SPAN 10
# knn pittsburg-bridges-SPAN 10
# gradient_boosting_machine pittsburg-bridges-SPAN 10
# adaboost pittsburg-bridges-SPAN 10
# mlp pittsburg-bridges-SPAN 10
# linear pittsburg-bridges-T-OR-D 20
# deep_gp_doubly_stochastic pittsburg-bridges-T-OR-D 10
# svm pittsburg-bridges-T-OR-D 10
# knn pittsburg-bridges-T-OR-D 10
# gradient_boosting_machine pittsburg-bridges-T-OR-D 10
# adaboost pittsburg-bridges-T-OR-D 10
# mlp pittsburg-bridges-T-OR-D 10
# linear pittsburg-bridges-TYPE 20
# deep_gp_doubly_stochastic pittsburg-bridges-TYPE 10
# svm pittsburg-bridges-TYPE 10
# knn pittsburg-bridges-TYPE 10
# gradient_boosting_machine pittsburg-bridges-TYPE 10
# adaboost pittsburg-bridges-TYPE 10
# mlp pittsburg-bridges-TYPE 10
# linear planning 20
# variationally_sparse_gp planning 10
# deep_gp_doubly_stochastic planning 10
# svm planning 10
# knn planning 10
# gradient_boosting_machine planning 9
# adaboost planning 10
# mlp planning 10
# linear plant-margin 20
# variationally_sparse_gp plant-margin 8
# svm plant-margin 10
# knn plant-margin 10
# gradient_boosting_machine plant-margin 10
# adaboost plant-margin 10
# mlp plant-margin 10
# linear plant-shape 20
# variationally_sparse_gp plant-shape 8
# deep_gp_doubly_stochastic plant-shape 2
# svm plant-shape 10
# knn plant-shape 10
# gradient_boosting_machine plant-shape 10
# adaboost plant-shape 10
# mlp plant-shape 10
# linear plant-texture 20
# variationally_sparse_gp plant-texture 5
# svm plant-texture 10
# knn plant-texture 10
# gradient_boosting_machine plant-texture 10
# adaboost plant-texture 10
# mlp plant-texture 10
# linear post-operative 20
# deep_gp_doubly_stochastic post-operative 10
# svm post-operative 10
# knn post-operative 10
# gradient_boosting_machine post-operative 10
# adaboost post-operative 10
# mlp post-operative 10
# linear primary-tumor 20
# variationally_sparse_gp primary-tumor 10
# deep_gp_doubly_stochastic primary-tumor 10
# svm primary-tumor 10
# knn primary-tumor 10
# gradient_boosting_machine primary-tumor 10
# adaboost primary-tumor 10
# mlp primary-tumor 10
# linear ringnorm 20
# deep_gp_doubly_stochastic ringnorm 1
# svm ringnorm 10
# knn ringnorm 10
# gradient_boosting_machine ringnorm 10
# adaboost ringnorm 10
# mlp ringnorm 10
# linear seeds 20
# variationally_sparse_gp seeds 10
# deep_gp_doubly_stochastic seeds 10
# svm seeds 10
# knn seeds 10
# gradient_boosting_machine seeds 10
# adaboost seeds 10
# mlp seeds 10
# linear semeion 20
# variationally_sparse_gp semeion 10
# svm semeion 10
# knn semeion 10
# gradient_boosting_machine semeion 10
# adaboost semeion 10
# mlp semeion 10
# linear soybean 20
# variationally_sparse_gp soybean 10
# deep_gp_doubly_stochastic soybean 10
# svm soybean 10
# knn soybean 10
# gradient_boosting_machine soybean 10
# adaboost soybean 10
# mlp soybean 10
# linear spambase 20
# variationally_sparse_gp spambase 9
# svm spambase 10
# knn spambase 10
# gradient_boosting_machine spambase 10
# adaboost spambase 10
# mlp spambase 10
# linear spect 20
# variationally_sparse_gp spect 10
# deep_gp_doubly_stochastic spect 10
# svm spect 10
# knn spect 10
# gradient_boosting_machine spect 10
# adaboost spect 10
# mlp spect 10
# linear spectf 20
# variationally_sparse_gp spectf 10
# deep_gp_doubly_stochastic spectf 10
# svm spectf 10
# knn spectf 10
# gradient_boosting_machine spectf 10
# adaboost spectf 10
# mlp spectf 10
# linear statlog-australian-credit 20
# variationally_sparse_gp statlog-australian-credit 10
# deep_gp_doubly_stochastic statlog-australian-credit 10
# svm statlog-australian-credit 10
# knn statlog-australian-credit 10
# gradient_boosting_machine statlog-australian-credit 10
# adaboost statlog-australian-credit 10
# mlp statlog-australian-credit 10
# linear statlog-german-credit 20
# variationally_sparse_gp statlog-german-credit 10
# deep_gp_doubly_stochastic statlog-german-credit 10
# svm statlog-german-credit 10
# knn statlog-german-credit 10
# gradient_boosting_machine statlog-german-credit 10
# adaboost statlog-german-credit 10
# mlp statlog-german-credit 10
# linear statlog-heart 20
# variationally_sparse_gp statlog-heart 10
# deep_gp_doubly_stochastic statlog-heart 10
# svm statlog-heart 10
# knn statlog-heart 10
# gradient_boosting_machine statlog-heart 10
# adaboost statlog-heart 10
# mlp statlog-heart 10
# linear statlog-image 20
# variationally_sparse_gp statlog-image 10
# deep_gp_doubly_stochastic statlog-image 10
# svm statlog-image 10
# knn statlog-image 10
# gradient_boosting_machine statlog-image 10
# adaboost statlog-image 10
# mlp statlog-image 10
# linear statlog-landsat 20
# svm statlog-landsat 10
# knn statlog-landsat 10
# gradient_boosting_machine statlog-landsat 10
# adaboost statlog-landsat 10
# mlp statlog-landsat 10
# linear statlog-shuttle 20
# svm statlog-shuttle 10
# knn statlog-shuttle 10
# gradient_boosting_machine statlog-shuttle 10
# adaboost statlog-shuttle 10
# mlp statlog-shuttle 10
# linear statlog-vehicle 20
# variationally_sparse_gp statlog-vehicle 10
# deep_gp_doubly_stochastic statlog-vehicle 10
# svm statlog-vehicle 10
# knn statlog-vehicle 10
# gradient_boosting_machine statlog-vehicle 10
# adaboost statlog-vehicle 10
# mlp statlog-vehicle 10
# linear steel-plates 20
# variationally_sparse_gp steel-plates 10
# deep_gp_doubly_stochastic steel-plates 9
# svm steel-plates 10
# knn steel-plates 10
# gradient_boosting_machine steel-plates 10
# adaboost steel-plates 10
# mlp steel-plates 10
# linear synthetic-control 20
# variationally_sparse_gp synthetic-control 10
# deep_gp_doubly_stochastic synthetic-control 6
# svm synthetic-control 10
# knn synthetic-control 10
# gradient_boosting_machine synthetic-control 10
# adaboost synthetic-control 10
# mlp synthetic-control 10
# linear teaching 20
# variationally_sparse_gp teaching 10
# deep_gp_doubly_stochastic teaching 4
# svm teaching 10
# knn teaching 10
# gradient_boosting_machine teaching 10
# adaboost teaching 10
# mlp teaching 10
# linear thyroid 20
# deep_gp_doubly_stochastic thyroid 1
# svm thyroid 10
# knn thyroid 10
# gradient_boosting_machine thyroid 10
# adaboost thyroid 10
# mlp thyroid 10
# linear tic-tac-toe 20
# variationally_sparse_gp tic-tac-toe 10
# deep_gp_doubly_stochastic tic-tac-toe 10
# svm tic-tac-toe 10
# knn tic-tac-toe 10
# gradient_boosting_machine tic-tac-toe 10
# adaboost tic-tac-toe 10
# mlp tic-tac-toe 10
# linear titanic 20
# variationally_sparse_gp titanic 10
# deep_gp_doubly_stochastic titanic 9
# svm titanic 10
# knn titanic 10
# gradient_boosting_machine titanic 10
# adaboost titanic 10
# mlp titanic 10
# linear trains 20
# deep_gp_doubly_stochastic trains 10
# svm trains 10
# knn trains 10
# gradient_boosting_machine trains 10
# adaboost trains 10
# mlp trains 10
# linear twonorm 20
# svm twonorm 10
# knn twonorm 10
# gradient_boosting_machine twonorm 10
# adaboost twonorm 10
# mlp twonorm 10
# linear vertebral-column-2clases 20
# variationally_sparse_gp vertebral-column-2clases 10
# deep_gp_doubly_stochastic vertebral-column-2clases 10
# svm vertebral-column-2clases 10
# knn vertebral-column-2clases 10
# gradient_boosting_machine vertebral-column-2clases 10
# adaboost vertebral-column-2clases 10
# mlp vertebral-column-2clases 10
# linear vertebral-column-3clases 20
# variationally_sparse_gp vertebral-column-3clases 10
# deep_gp_doubly_stochastic vertebral-column-3clases 10
# svm vertebral-column-3clases 10
# knn vertebral-column-3clases 10
# gradient_boosting_machine vertebral-column-3clases 10
# adaboost vertebral-column-3clases 10
# mlp vertebral-column-3clases 10
# linear wall-following 20
# variationally_sparse_gp wall-following 10
# deep_gp_doubly_stochastic wall-following 1
# svm wall-following 10
# knn wall-following 10
# gradient_boosting_machine wall-following 10
# adaboost wall-following 10
# mlp wall-following 10
# linear waveform 20
# variationally_sparse_gp waveform 10
# deep_gp_doubly_stochastic waveform 4
# svm waveform 10
# knn waveform 10
# gradient_boosting_machine waveform 10
# adaboost waveform 10
# mlp waveform 10
# linear waveform-noise 20
# variationally_sparse_gp waveform-noise 9
# svm waveform-noise 10
# knn waveform-noise 10
# gradient_boosting_machine waveform-noise 10
# adaboost waveform-noise 10
# mlp waveform-noise 10
# linear wine 20
# variationally_sparse_gp wine 5
# deep_gp_doubly_stochastic wine 10
# svm wine 10
# knn wine 9
# gradient_boosting_machine wine 10
# adaboost wine 10
# mlp wine 10
# linear wine-quality-red 20
# variationally_sparse_gp wine-quality-red 1
# deep_gp_doubly_stochastic wine-quality-red 10
# svm wine-quality-red 10
# knn wine-quality-red 10
# gradient_boosting_machine wine-quality-red 10
# adaboost wine-quality-red 10
# mlp wine-quality-red 10
# linear wine-quality-white 20
# deep_gp_doubly_stochastic wine-quality-white 8
# svm wine-quality-white 10
# knn wine-quality-white 10
# gradient_boosting_machine wine-quality-white 10
# adaboost wine-quality-white 10
# mlp wine-quality-white 10
# linear yeast 20
# variationally_sparse_gp yeast 1
# deep_gp_doubly_stochastic yeast 10
# svm yeast 10
# knn yeast 10
# gradient_boosting_machine yeast 10
# adaboost yeast 10
# mlp yeast 10
# linear zoo 20
# deep_gp_doubly_stochastic zoo 10
# svm zoo 10
# knn zoo 10
# gradient_boosting_machine zoo 10
# adaboost zoo 10
# mlp zoo 10
# /vol/sml/hrs13/environments/py35cpu/lib/python3.5/site-packages/ipykernel_launcher.py:62: RuntimeWarning: Mean of empty slice
# /vol/sml/hrs13/environments/py35cpu/lib/python3.5/site-packages/numpy/lib/function_base.py:4033: RuntimeWarning: All-NaN slice encountered
#   r = func(a, **kwargs)

# %%
print('test loglikelihood')
display(HTML(pandas.DataFrame(results['test_loglik']['table'], columns=fields).to_html(index=False)))
# print(pandas.DataFrame(results['test_loglik']['table'], columns=fields).to_latex())

print('test accuracy')
display(HTML(pandas.DataFrame(results['test_acc']['table'], columns=fields).to_html(index=False)))
# Out:
# test loglikelihood
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>dataset</th>
#       <th>N</th>
#       <th>D</th>
#       <th>K</th>
#       <th>lin</th>
#       <th>SVGP</th>
#       <th>SVGP_mb</th>
#       <th>DGP</th>
#       <th>svm</th>
#       <th>knn</th>
#       <th>gbm</th>
#       <th>ab</th>
#       <th>mlp</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>abalone</td>
#       <td>4177</td>
#       <td>9</td>
#       <td>3</td>
#       <td>-0.760(0.039)</td>
#       <td>-2.150(0.181)</td>
#       <td></td>
#       <td>-1.825(0.170)</td>
#       <td>-0.746(0.040)</td>
#       <td>-2.564(0.324)</td>
#       <td>-0.654(0.030)</td>
#       <td>-1.053(0.007)</td>
#       <td>-0.708(0.038)</td>
#     </tr>
#     <tr>
#       <td>acute-infl</td>
#       <td>120</td>
#       <td>7</td>
#       <td>2</td>
#       <td>-0.049(0.015)</td>
#       <td>-0.008(0.002)</td>
#       <td></td>
#       <td>-0.063(0.008)</td>
#       <td>-0.018(0.001)</td>
#       <td>-0.000(0.000)</td>
#       <td>-0.000(0.000)</td>
#       <td>-0.025(0.063)</td>
#       <td>-0.030(0.008)</td>
#     </tr>
#     <tr>
#       <td>acute-neph</td>
#       <td>120</td>
#       <td>7</td>
#       <td>2</td>
#       <td>-0.031(0.008)</td>
#       <td>-0.007(0.002)</td>
#       <td></td>
#       <td>-0.051(0.006)</td>
#       <td>-0.019(0.001)</td>
#       <td>-0.000(0.000)</td>
#       <td>-0.000(0.000)</td>
#       <td>-0.085(0.256)</td>
#       <td>-0.017(0.004)</td>
#     </tr>
#     <tr>
#       <td>adult</td>
#       <td>48842</td>
#       <td>15</td>
#       <td>2</td>
#       <td>-0.342(0.005)</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>-0.359(0.005)</td>
#       <td>-1.146(0.048)</td>
#       <td>-0.290(0.004)</td>
#       <td>-0.665(0.000)</td>
#       <td>-0.315(0.005)</td>
#     </tr>
#     <tr>
#       <td>annealing</td>
#       <td>898</td>
#       <td>32</td>
#       <td>5</td>
#       <td>-0.365(0.061)</td>
#       <td>-0.743(0.358)</td>
#       <td></td>
#       <td>-1.051(0.333)</td>
#       <td>-0.342(0.086)</td>
#       <td>-0.769(0.394)</td>
#       <td>-0.104(0.062)</td>
#       <td>-1.219(0.021)</td>
#       <td>-0.279(0.052)</td>
#     </tr>
#     <tr>
#       <td>arrhythmia</td>
#       <td>452</td>
#       <td>263</td>
#       <td>13</td>
#       <td>-1.343(0.298)</td>
#       <td>-1.162(0.285)</td>
#       <td></td>
#       <td>-1.270(0.225)</td>
#       <td>-1.071(0.143)</td>
#       <td>-5.885(1.417)</td>
#       <td>-1.331(0.344)</td>
#       <td>-2.568(0.360)</td>
#       <td>-1.333(0.287)</td>
#     </tr>
#     <tr>
#       <td>audiology-</td>
#       <td>196</td>
#       <td>60</td>
#       <td>18</td>
#       <td>-1.072(0.229)</td>
#       <td>-0.914(0.338)</td>
#       <td></td>
#       <td>-1.140(0.311)</td>
#       <td>-1.453(0.216)</td>
#       <td>-4.130(1.691)</td>
#       <td>-0.979(0.378)</td>
#       <td>-2.904(0.326)</td>
#       <td>-0.867(0.215)</td>
#     </tr>
#     <tr>
#       <td>balance-sc</td>
#       <td>625</td>
#       <td>5</td>
#       <td>3</td>
#       <td>-0.363(0.107)</td>
#       <td>-0.039(0.046)</td>
#       <td></td>
#       <td>-0.018(0.014)</td>
#       <td>-0.220(0.074)</td>
#       <td>-2.087(0.818)</td>
#       <td>-0.397(0.119)</td>
#       <td>-0.994(0.009)</td>
#       <td>-0.139(0.050)</td>
#     </tr>
#     <tr>
#       <td>balloons</td>
#       <td>16</td>
#       <td>5</td>
#       <td>2</td>
#       <td>-0.708(0.355)</td>
#       <td></td>
#       <td></td>
#       <td>-0.615(0.119)</td>
#       <td>-0.617(0.139)</td>
#       <td>-0.576(0.161)</td>
#       <td>-1.630(2.162)</td>
#       <td>-2.676(2.902)</td>
#       <td>-0.652(0.463)</td>
#     </tr>
#     <tr>
#       <td>bank</td>
#       <td>4521</td>
#       <td>17</td>
#       <td>2</td>
#       <td>-0.271(0.028)</td>
#       <td>-0.252(0.024)</td>
#       <td></td>
#       <td>-0.253(0.024)</td>
#       <td>-0.286(0.029)</td>
#       <td>-1.143(0.224)</td>
#       <td>-0.235(0.020)</td>
#       <td>-0.646(0.002)</td>
#       <td>-0.281(0.036)</td>
#     </tr>
#     <tr>
#       <td>blood</td>
#       <td>748</td>
#       <td>5</td>
#       <td>2</td>
#       <td>-0.469(0.070)</td>
#       <td>-0.471(0.075)</td>
#       <td></td>
#       <td>-0.491(0.079)</td>
#       <td>-0.503(0.070)</td>
#       <td>-1.861(0.769)</td>
#       <td>-0.523(0.090)</td>
#       <td>-0.677(0.005)</td>
#       <td>-0.469(0.072)</td>
#     </tr>
#     <tr>
#       <td>breast-can</td>
#       <td>286</td>
#       <td>10</td>
#       <td>2</td>
#       <td>-0.115(0.032)</td>
#       <td>-0.079(0.028)</td>
#       <td></td>
#       <td>-0.118(0.030)</td>
#       <td>-0.132(0.048)</td>
#       <td>-0.671(0.601)</td>
#       <td>-0.088(0.135)</td>
#       <td>-0.286(0.437)</td>
#       <td>-0.133(0.042)</td>
#     </tr>
#     <tr>
#       <td>breast-can</td>
#       <td>699</td>
#       <td>10</td>
#       <td>2</td>
#       <td>-0.106(0.073)</td>
#       <td>-0.048(0.006)</td>
#       <td></td>
#       <td>-0.105(0.063)</td>
#       <td>-0.105(0.066)</td>
#       <td>-0.359(0.304)</td>
#       <td>-0.113(0.094)</td>
#       <td>-0.507(0.036)</td>
#       <td>-0.107(0.090)</td>
#     </tr>
#     <tr>
#       <td>breast-can</td>
#       <td>569</td>
#       <td>31</td>
#       <td>2</td>
#       <td>-0.074(0.038)</td>
#       <td>-0.063(0.036)</td>
#       <td></td>
#       <td>-0.070(0.032)</td>
#       <td>-0.074(0.031)</td>
#       <td>-0.251(0.228)</td>
#       <td>-0.128(0.108)</td>
#       <td>-0.457(0.032)</td>
#       <td>-0.076(0.059)</td>
#     </tr>
#     <tr>
#       <td>breast-can</td>
#       <td>198</td>
#       <td>34</td>
#       <td>2</td>
#       <td>-0.541(0.192)</td>
#       <td>-0.530(0.152)</td>
#       <td></td>
#       <td>-0.516(0.134)</td>
#       <td>-0.529(0.131)</td>
#       <td>-2.227(1.462)</td>
#       <td>-0.656(0.229)</td>
#       <td>-0.602(0.050)</td>
#       <td>-0.541(0.250)</td>
#     </tr>
#     <tr>
#       <td>breast-tis</td>
#       <td>106</td>
#       <td>10</td>
#       <td>6</td>
#       <td>-0.747(0.113)</td>
#       <td></td>
#       <td></td>
#       <td>-0.217(0.255)</td>
#       <td>-0.580(0.129)</td>
#       <td>-0.866(1.501)</td>
#       <td>-0.424(0.562)</td>
#       <td>-1.252(0.715)</td>
#       <td>-0.430(0.113)</td>
#     </tr>
#     <tr>
#       <td>car</td>
#       <td>1728</td>
#       <td>7</td>
#       <td>4</td>
#       <td>-0.455(0.032)</td>
#       <td>-0.044(0.037)</td>
#       <td></td>
#       <td>-0.018(0.011)</td>
#       <td>-0.076(0.034)</td>
#       <td>-0.195(0.014)</td>
#       <td>-0.092(0.027)</td>
#       <td>-0.487(0.100)</td>
#       <td>-0.074(0.022)</td>
#     </tr>
#     <tr>
#       <td>cardiotoco</td>
#       <td>2126</td>
#       <td>22</td>
#       <td>10</td>
#       <td>-0.663(0.037)</td>
#       <td>-0.814(0.114)</td>
#       <td></td>
#       <td>-0.703(0.085)</td>
#       <td>-0.439(0.035)</td>
#       <td>-1.745(0.225)</td>
#       <td>-0.362(0.060)</td>
#       <td>-1.970(0.140)</td>
#       <td>-0.390(0.049)</td>
#     </tr>
#     <tr>
#       <td>cardiotoco</td>
#       <td>2126</td>
#       <td>22</td>
#       <td>3</td>
#       <td>-0.228(0.022)</td>
#       <td>-0.346(0.074)</td>
#       <td></td>
#       <td>-0.289(0.071)</td>
#       <td>-0.196(0.022)</td>
#       <td>-0.504(0.171)</td>
#       <td>-0.125(0.028)</td>
#       <td>-0.897(0.019)</td>
#       <td>-0.177(0.055)</td>
#     </tr>
#     <tr>
#       <td>chess-krvk</td>
#       <td>28056</td>
#       <td>7</td>
#       <td>18</td>
#       <td>-1.378(0.010)</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>-0.093(0.008)</td>
#       <td>-0.449(0.050)</td>
#       <td>-0.005(0.004)</td>
#       <td>-1.605(0.201)</td>
#       <td>-0.022(0.004)</td>
#     </tr>
#     <tr>
#       <td>chess-krvk</td>
#       <td>3196</td>
#       <td>37</td>
#       <td>2</td>
#       <td>-0.056(0.009)</td>
#       <td>-0.029(0.006)</td>
#       <td></td>
#       <td>-0.038(0.006)</td>
#       <td>-0.020(0.008)</td>
#       <td>-0.232(0.088)</td>
#       <td>-0.008(0.012)</td>
#       <td>-0.010(0.007)</td>
#       <td>-0.021(0.017)</td>
#     </tr>
#     <tr>
#       <td>congressio</td>
#       <td>435</td>
#       <td>17</td>
#       <td>2</td>
#       <td>-0.697(0.100)</td>
#       <td>-0.653(0.049)</td>
#       <td></td>
#       <td>-0.668(0.056)</td>
#       <td>-0.661(0.026)</td>
#       <td>-2.227(1.124)</td>
#       <td>-0.703(0.064)</td>
#       <td>-0.687(0.003)</td>
#       <td>-0.803(0.175)</td>
#     </tr>
#     <tr>
#       <td>conn-bench</td>
#       <td>208</td>
#       <td>61</td>
#       <td>2</td>
#       <td>-0.08
# test accuracy
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>dataset</th>
#       <th>N</th>
#       <th>D</th>
#       <th>K</th>
#       <th>lin</th>
#       <th>SVGP</th>
#       <th>SVGP_mb</th>
#       <th>DGP</th>
#       <th>svm</th>
#       <th>knn</th>
#       <th>gbm</th>
#       <th>ab</th>
#       <th>mlp</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>abalone</td>
#       <td>4177</td>
#       <td>9</td>
#       <td>3</td>
#       <td>0.636(0.029)</td>
#       <td>0.664(0.024)</td>
#       <td></td>
#       <td>0.669(0.026)</td>
#       <td>0.661(0.024)</td>
#       <td>0.633(0.029)</td>
#       <td>0.696(0.022)</td>
#       <td>0.688(0.024)</td>
#       <td>0.668(0.028)</td>
#     </tr>
#     <tr>
#       <td>acute-infl</td>
#       <td>120</td>
#       <td>7</td>
#       <td>2</td>
#       <td>1.000(0.000)</td>
#       <td>1.000(0.000)</td>
#       <td></td>
#       <td>1.000(0.000)</td>
#       <td>1.000(0.000)</td>
#       <td>1.000(0.000)</td>
#       <td>1.000(0.000)</td>
#       <td>0.983(0.050)</td>
#       <td>1.000(0.000)</td>
#     </tr>
#     <tr>
#       <td>acute-neph</td>
#       <td>120</td>
#       <td>7</td>
#       <td>2</td>
#       <td>1.000(0.000)</td>
#       <td>1.000(0.000)</td>
#       <td></td>
#       <td>1.000(0.000)</td>
#       <td>1.000(0.000)</td>
#       <td>1.000(0.000)</td>
#       <td>1.000(0.000)</td>
#       <td>0.992(0.025)</td>
#       <td>1.000(0.000)</td>
#     </tr>
#     <tr>
#       <td>adult</td>
#       <td>48842</td>
#       <td>15</td>
#       <td>2</td>
#       <td>0.843(0.005)</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>0.849(0.004)</td>
#       <td>0.830(0.003)</td>
#       <td>0.868(0.004)</td>
#       <td>0.859(0.005)</td>
#       <td>0.854(0.004)</td>
#     </tr>
#     <tr>
#       <td>annealing</td>
#       <td>898</td>
#       <td>32</td>
#       <td>5</td>
#       <td>0.848(0.041)</td>
#       <td>0.892(0.046)</td>
#       <td></td>
#       <td>0.862(0.043)</td>
#       <td>0.876(0.044)</td>
#       <td>0.880(0.041)</td>
#       <td>0.967(0.017)</td>
#       <td>0.870(0.036)</td>
#       <td>0.890(0.047)</td>
#     </tr>
#     <tr>
#       <td>arrhythmia</td>
#       <td>452</td>
#       <td>263</td>
#       <td>13</td>
#       <td>0.707(0.092)</td>
#       <td>0.761(0.056)</td>
#       <td></td>
#       <td>0.761(0.048)</td>
#       <td>0.674(0.051)</td>
#       <td>0.615(0.048)</td>
#       <td>0.754(0.061)</td>
#       <td>0.613(0.070)</td>
#       <td>0.678(0.056)</td>
#     </tr>
#     <tr>
#       <td>audiology-</td>
#       <td>196</td>
#       <td>60</td>
#       <td>18</td>
#       <td>0.795(0.096)</td>
#       <td>0.755(0.069)</td>
#       <td></td>
#       <td>0.730(0.081)</td>
#       <td>0.630(0.105)</td>
#       <td>0.535(0.081)</td>
#       <td>0.810(0.073)</td>
#       <td>0.265(0.125)</td>
#       <td>0.705(0.072)</td>
#     </tr>
#     <tr>
#       <td>balance-sc</td>
#       <td>625</td>
#       <td>5</td>
#       <td>3</td>
#       <td>0.863(0.048)</td>
#       <td>0.986(0.019)</td>
#       <td></td>
#       <td>0.997(0.006)</td>
#       <td>0.916(0.036)</td>
#       <td>0.835(0.062)</td>
#       <td>0.870(0.049)</td>
#       <td>0.908(0.042)</td>
#       <td>0.970(0.026)</td>
#     </tr>
#     <tr>
#       <td>balloons</td>
#       <td>16</td>
#       <td>5</td>
#       <td>2</td>
#       <td>0.500(0.316)</td>
#       <td></td>
#       <td></td>
#       <td>0.600(0.300)</td>
#       <td>0.600(0.300)</td>
#       <td>0.600(0.300)</td>
#       <td>0.650(0.450)</td>
#       <td>0.400(0.300)</td>
#       <td>0.550(0.350)</td>
#     </tr>
#     <tr>
#       <td>bank</td>
#       <td>4521</td>
#       <td>17</td>
#       <td>2</td>
#       <td>0.892(0.018)</td>
#       <td>0.892(0.015)</td>
#       <td></td>
#       <td>0.891(0.017)</td>
#       <td>0.892(0.013)</td>
#       <td>0.890(0.014)</td>
#       <td>0.900(0.011)</td>
#       <td>0.892(0.015)</td>
#       <td>0.894(0.013)</td>
#     </tr>
#     <tr>
#       <td>blood</td>
#       <td>748</td>
#       <td>5</td>
#       <td>2</td>
#       <td>0.780(0.055)</td>
#       <td>0.790(0.054)</td>
#       <td></td>
#       <td>0.781(0.048)</td>
#       <td>0.781(0.050)</td>
#       <td>0.767(0.041)</td>
#       <td>0.768(0.041)</td>
#       <td>0.776(0.046)</td>
#       <td>0.785(0.043)</td>
#     </tr>
#     <tr>
#       <td>breast-can</td>
#       <td>286</td>
#       <td>10</td>
#       <td>2</td>
#       <td>0.979(0.032)</td>
#       <td>0.969(0.019)</td>
#       <td></td>
#       <td>0.969(0.019)</td>
#       <td>0.955(0.031)</td>
#       <td>0.821(0.065)</td>
#       <td>0.990(0.016)</td>
#       <td>0.990(0.016)</td>
#       <td>0.959(0.030)</td>
#     </tr>
#     <tr>
#       <td>breast-can</td>
#       <td>699</td>
#       <td>10</td>
#       <td>2</td>
#       <td>0.964(0.026)</td>
#       <td>0.990(0.007)</td>
#       <td></td>
#       <td>0.967(0.024)</td>
#       <td>0.969(0.022)</td>
#       <td>0.970(0.026)</td>
#       <td>0.967(0.023)</td>
#       <td>0.954(0.025)</td>
#       <td>0.966(0.031)</td>
#     </tr>
#     <tr>
#       <td>breast-can</td>
#       <td>569</td>
#       <td>31</td>
#       <td>2</td>
#       <td>0.967(0.021)</td>
#       <td>0.972(0.013)</td>
#       <td></td>
#       <td>0.975(0.016)</td>
#       <td>0.974(0.014)</td>
#       <td>0.972(0.020)</td>
#       <td>0.960(0.030)</td>
#       <td>0.958(0.033)</td>
#       <td>0.965(0.022)</td>
#     </tr>
#     <tr>
#       <td>breast-can</td>
#       <td>198</td>
#       <td>34</td>
#       <td>2</td>
#       <td>0.765(0.100)</td>
#       <td>0.761(0.084)</td>
#       <td></td>
#       <td>0.770(0.084)</td>
#       <td>0.755(0.085)</td>
#       <td>0.715(0.071)</td>
#       <td>0.760(0.062)</td>
#       <td>0.750(0.095)</td>
#       <td>0.790(0.070)</td>
#     </tr>
#     <tr>
#       <td>breast-tis</td>
#       <td>106</td>
#       <td>10</td>
#       <td>6</td>
#       <td>0.791(0.108)</td>
#       <td></td>
#       <td></td>
#       <td>0.964(0.060)</td>
#       <td>0.873(0.116)</td>
#       <td>0.818(0.091)</td>
#       <td>0.955(0.061)</td>
#       <td>0.464(0.111)</td>
#       <td>0.936(0.071)</td>
#     </tr>
#     <tr>
#       <td>car</td>
#       <td>1728</td>
#       <td>7</td>
#       <td>4</td>
#       <td>0.805(0.021)</td>
#       <td>0.987(0.009)</td>
#       <td></td>
#       <td>0.995(0.007)</td>
#       <td>0.975(0.013)</td>
#       <td>0.951(0.010)</td>
#       <td>0.966(0.014)</td>
#       <td>0.828(0.045)</td>
#       <td>0.979(0.011)</td>
#     </tr>
#     <tr>
#       <td>cardiotoco</td>
#       <td>2126</td>
#       <td>22</td>
#       <td>10</td>
#       <td>0.777(0.024)</td>
#       <td>0.847(0.016)</td>
#       <td></td>
#       <td>0.849(0.014)</td>
#       <td>0.841(0.017)</td>
#       <td>0.745(0.034)</td>
#       <td>0.895(0.021)</td>
#       <td>0.541(0.073)</td>
#       <td>0.853(0.017)</td>
#     </tr>
#     <tr>
#       <td>cardiotoco</td>
#       <td>2126</td>
#       <td>22</td>
#       <td>3</td>
#       <td>0.910(0.016)</td>
#       <td>0.924(0.012)</td>
#       <td></td>
#       <td>0.926(0.011)</td>
#       <td>0.921(0.010)</td>
#       <td>0.906(0.015)</td>
#       <td>0.962(0.010)</td>
#       <td>0.895(0.063)</td>
#       <td>0.935(0.012)</td>
#     </tr>
#     <tr>
#       <td>chess-krvk</td>
#       <td>28056</td>
#       <td>7</td>
#       <td>18</td>
#       <td>0.572(0.010)</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>0.966(0.005)</td>
#       <td>0.921(0.004)</td>
#       <td>1.000(0.000)</td>
#       <td>0.540(0.083)</td>
#       <td>0.994(0.002)</td>
#     </tr>
#     <tr>
#       <td>chess-krvk</td>
#       <td>3196</td>
#       <td>37</td>
#       <td>2</td>
#       <td>0.980(0.005)</td>
#       <td>0.997(0.002)</td>
#       <td></td>
#       <td>0.995(0.003)</td>
#       <td>0.994(0.004)</td>
#       <td>0.959(0.007)</td>
#       <td>0.999(0.001)</td>
#       <td>0.999(0.001)</td>
#       <td>0.997(0.003)</td>
#     </tr>
#     <tr>
#       <td>congressio</td>
#       <td>435</td>
#       <td>17</td>
#       <td>2</td>
#       <td>0.618(0.043)</td>
#       <td>0.600(0.054)</td>
#       <td></td>
#       <td>0.564(0.062)</td>
#       <td>0.630(0.061)</td>
#       <td>0.564(0.068)</td>
#       <td>0.580(0.077)</td>
#       <td>0.582(0.056)</td>
#       <td>0.566(0.059)</td>
#     </tr>
#     <tr>
#       <td>conn-bench</td>
#       <td>208</td>
#       <td>61</td>
#       <td>2</td>
#       <td>0.986(0.030)</td>
#       <td>0.981(0.032)</td>
#       <td></td>
#       <td>0.976(0.032)</td>
#       <td>0.971(0.032)</td>
#       <td>0.900(0.054)</td>
#       <td>1.000(0.000)</td>

# %%
# fields = ['dataset', 'N', 'D']

                
# colours = ['C{}'.format(i) for i in range(10)]

# fields = fields + [m[1] for m in models_names]
# results = {f:[] for f in fields}


# for dataset in regression_datasets:
    
#     fig, axs = plt.subplots(1, 2, figsize=(10, 5))

#     results['dataset'].append(dataset)
#     results['N'].append(ALL_REGRESSION_DATATSETS[dataset].N)
#     results['D'].append(ALL_REGRESSION_DATATSETS[dataset].D)

#     for (model, name), c in zip(models_names, colours):
#         with Database('../results/results.db') as db:
#             d = {'model':model, 'dataset':dataset}

#             res = db.read('active_learning_continuous', ['total_loglik', 'total_rmse'], d) 
#         if len(res)>0:
#             test_ll = res[0][0]
#             test_acc = res[0][1]

#             axs[0].plot(test_ll, label=model, color=c)r
#             axs[1].plot(test_acc, label=model, color=c)
#     axs[0].set_ylim(-10, 10)
#     plt.title('{} {} {}'.format(dataset,
#                                    ALL_REGRESSION_DATATSETS[dataset].N,
#                                    ALL_REGRESSION_DATATSETS[dataset].D))
#     plt.legend()
#     plt.show()

# %%
# fields = ['dataset', 'N', 'D', 'K']

# models_names = [['linear', 'lin'],
#                 ['variationally_sparse_gp', 'SVGP'],
#                 ['deep_gp_doubly_stochastic','DGP'],
#                 ['svm', 'svm'],
#                 ['knn', 'knn'],
#                 ['naive_bayes', 'nb'],
#                 ['decision_tree', 'dt'],
#                 ['random_forest', 'rf'],
#                 ['gradient_boosting_machine', 'gbm'],
#                 ['adaboost', 'ab'],
#                 ['mlp', 'mlp'],
#                 ]
                
# colours = ['C{}'.format(i) for i in range(10)]

# fields = fields + [m[1] for m in models_names]
# results = {f:[] for f in fields}


# for dataset in classification_datasets[:4]:  # don't show them all...
    
#     fig, axs = plt.subplots(1, 2, figsize=(10, 5))

#     results['dataset'].append(dataset)
#     results['N'].append(ALL_CLASSIFICATION_DATATSETS[dataset].N)
#     results['D'].append(ALL_CLASSIFICATION_DATATSETS[dataset].D)
#     results['K'].append(ALL_CLASSIFICATION_DATATSETS[dataset].K)

#     for (model, name), c in zip(models_names, colours):
#         with Database('../results/results.db') as db:
#             d = {'model':model, 'dataset':dataset}

#             res = db.read('active_learning_discrete', ['test_loglik', 'total_acc'], d) 
#         if len(res)>0:
#             test_ll = res[0][0]
#             test_acc = res[0][1]

#             axs[0].plot(test_ll, label=model, color=c)
#             axs[1].plot(test_acc, label=model, color=c)

#     plt.title('{} {} {} {}'.format(dataset,
#                                    ALL_CLASSIFICATION_DATATSETS[dataset].N,
#                                    ALL_CLASSIFICATION_DATATSETS[dataset].D,
#                                    ALL_CLASSIFICATION_DATATSETS[dataset].K))
#     plt.legend()
#     plt.show()
